# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
lower_blue = np.array([25//4,170,70])
upper_blue = np.array([3*25//4,255,255])

# %%
img = cv2.imread("claro.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

mask = cv2.inRange(img_hsv, lower_blue, upper_blue)

mask = cv2.GaussianBlur(mask, (3,3), 0)
result = cv2.bitwise_and(img, img, mask=mask)

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.axis("off")
plt.imshow(img)

plt.subplot(1,2,2)
plt.axis("off")
plt.imshow(result, cmap="gray")
plt.show()

# %%
img = cv2.imread("oscuro.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

img_hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

lower_blue = np.array([6,100,50])
upper_blue = np.array([18,255,255])

mask = cv2.inRange(img_hsv, lower_blue, upper_blue)

mask = cv2.GaussianBlur(mask, (3,3), 0)
result = cv2.bitwise_and(img, img, mask=mask)

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.axis("off")
plt.imshow(img)

plt.subplot(1,2,2)
plt.axis("off")
plt.imshow(result, cmap="gray")
plt.show()
